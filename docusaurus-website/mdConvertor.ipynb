# %% [markdown]
# # مبدل فایل سرفصل درس
#
# این برنامه تبدیل فایل سرفصل درسها به صورت مارک داون که قابل درج در گیت‌هاب باشد را انجام می‌دهد.
#
# فرض بر این هست که سرفصل همه درسها در یک فایل مارک‌داون است، این برنامه بخشهای مختلف هر درس از قبیل،‌عنوان، تعداد واحد، نوع درسها و ... را استخراج کرده و مشخصات ار درس را در یک فایل مارک‌داون قرار می‌دهد.
#
#
# ## M. Amintoosi

# %%
# !pip install markdown-strings
# !pip install mkdocs
# !pip install docx2md
# !pip install jdatetime
# !pip install Markdown2docx

# %%
# !docx2md -m "../input/DS-Chart.docx" ../input/DS-Chart.md 
# !docx2md -m "../input/preface.docx" ../input/preface.md
# Out:
# [parse_r] softHyphen
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# # ** skip tcPr
# ...

# %%
# %run ds_parser.py
# Out:
# 🚀 Starting generation at: 1404/11/20 - 16:46
#
# 📈 Extraction Statistics:
# Total valid courses: 54
#
# 📊 Course types distribution:
# course_type
# تخصصی الزامی     26
# تخصصی اختیاری    17
# پایه              7
# مهارتی            4
# Name: count, dtype: int64
#
# 📊 Has exercises distribution:
# has_exercises
# دارد     37
#          10
# ندارد     7
# Name: count, dtype: int64
#
# 📝 Generating individual course files...
#
# 🎯 Generating files for 54 courses...
# 📁 Folder structure: {'پایه': 'base', 'تخصصی الزامی': 'mandatory', 'تخصصی اختیاری': 'elective', 'مهارتی': 'skill', 'سایر': 'other'}
# 📚 Created 54 course mappings
# 📊 Alphabetical sorting by Persian title:
#    1. [تخصصی اختیاری] آشنایی با نظریه بازی ها
#    2. [تخصصی اختیاری] آشنایی با یادگیری عمیق
#    3. [تخصصی اختیاری] آمار و احتمال فازی
#    4. [تخصصی اختیاری] برنامه‌نویسی موبایل
#    5. [تخصصی اختیاری] برنامه‌نویسی وب
#    6. [تخصصی اختیاری] تحلیل بقا مقدماتی
#    7. [تخصصی اختیاری] تحلیل سری های زمانی کاربردی ۲
# ...

# %%
# %run test_parser.py

# %%
# from Markdown2docx import Markdown2docx
# project = Markdown2docx('../input/preface')
# project.eat_soup()
# project.save()

# %%
# !pip install md2docx-python

# %%
# from md2docx_python.src.md2docx_python import markdown_to_word

# # Define the paths to your files
# markdown_file = "../input/DS-Chart.md"
# word_file = "DS.docx"

# # Convert the Markdown file to a Word document
# markdown_to_word(markdown_file, word_file)

# %%
# from md2docx_python.src.docx2md_python import word_to_markdown

# # Define the paths to your files
# word_file = "../input/DS-Chart.docx"
# markdown_file = "test_document_output.md"

# # Convert the Word document to a Markdown file
# word_to_markdown(word_file, markdown_file)
