# %% [markdown]
# # مبدل فایل سرفصل درس
#
# این برنامه تبدیل فایل سرفصل درسها به صورت مارک داون که قابل درج در گیت‌هاب باشد را انجام می‌دهد.
#
# فرض بر این هست که سرفصل همه درسها در یک فایل مارک‌داون است، این برنامه بخشهای مختلف هر درس از قبیل،‌عنوان، تعداد واحد، نوع درسها و ... را استخراج کرده و مشخصات ار درس را در یک فایل مارک‌داون قرار می‌دهد.
#
#
# ## M. Amintoosi

# %%
# !pip install markdown-strings
# !pip install mkdocs
# !pip install docx2md
# !pip install jdatetime

# %%
# !docx2md -m "../input/DS-Chart.docx" ../input/DS-Chart.md 
# !docx2md -m "../input/preface.docx" ../input/preface.md

# %%
# %run ds_parser.py
# Out:
# 🚀 Starting generation at: 1404/11/14 - 13:16
# ✅ Created: docs/category\base\_category_.json
# ✅ Created: docs/category\mandatory\_category_.json
# ✅ Created: docs/category\elective\_category_.json
# ✅ Created: docs/category\skill\_category_.json
#
# 📈 Extraction Statistics:
# Total valid courses: 37
#
# 📊 Course types distribution:
# course_type
# تخصصی الزامی    26
# پایه             7
# مهارتی           4
# Name: count, dtype: int64
#
# 📊 Has exercises distribution:
# has_exercises
# دارد     27
#           5
# ندارد     5
# Name: count, dtype: int64
#
# 📝 Generating individual course files...
#
# 🎯 Generating files for 37 courses...
# 📁 Folder structure: {'پایه': 'base', 'تخصصی الزامی': 'mandatory', 'تخصصی اختیاری': 'elective', 'مهارتی': 'skill', '': 'other'}
# 📚 Created 37 course mappings
#
# ✅ Successfully generated 37 files
#
# 📁 Files generated in folders:
#   📂 base/: 7 files
#   📂 mandatory/: 26 files
#   📂 skill/: 4 files
#
# 📊 Generating summary tables...
#
# 📊 Generating summary tables...
# ✅ Summary tables generated: ./docs/summary-tables.md
# ✅ Read preface content from: ../input/preface.md
# ✅ Index file generated: ./docs/index.md
# ✅ Category config: ./docs/category/curriculum/_category_.json
# ✅ Category config: ./docs/category/base/_category_.json
# ✅ Category config: ./docs/category/mandatory/_category_.json
# ✅ Category config: ./docs/category/skill/_category_.json
# ✅ Category config: ./docs/category/elective/_category_.json
# ✅ Docs repo-structure generated at: 1404/11/14 - 13:16
#
# ============================================================
# ✅ GENERATION COMPLETE!
# ============================================================
# 📅 Generated at: 1404/11/14 - 13:16
# 📚 Total courses: 37
# 📁 English folders: base/, mandatory/, elective/, skill/, other/
# 🌐 Access URLs:
#    - /docs/category/curriculum/
#    - /docs/category/base/
#    - /docs/category/mandatory/
#    - /docs/category/elective/
#    - /docs/category/skill/
# ============================================================

# %%
# %run test_parser.py
