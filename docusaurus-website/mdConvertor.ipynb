# %% [markdown]
# # مبدل فایل سرفصل درس
#
# این برنامه تبدیل فایل سرفصل درسها به صورت مارک داون که قابل درج در گیت‌هاب باشد را انجام می‌دهد.
#
# فرض بر این هست که سرفصل همه درسها در یک فایل مارک‌داون است، این برنامه بخشهای مختلف هر درس از قبیل،‌عنوان، تعداد واحد، نوع درسها و ... را استخراج کرده و مشخصات ار درس را در یک فایل مارک‌داون قرار می‌دهد.
#
#
# ## M. Amintoosi

# %%
# !pip install markdown-strings
# !pip install mkdocs
# !pip install docx2md

# %%
# !docx2md -m "../input/DS-Chart.docx" ../input/DS-Chart.md

# %%
# %run ds_parser.py
# Out:
# 🔍 Starting DS Course Parser...
# 📖 File size: 108171 characters
# 📚 Found 37 course sections
#
# ============================================================
# 📋 Processing course section 1/37
# ============================================================
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: ریاضی عمومی ۱
# ✅ Found English title: Calculus I
# 📝 Course type: پایه
# 📝 Unit type: نظری
# ✅ Extracted data: ریاضی عمومی ۱
#
# ============================================================
# 📋 Processing course section 2/37
# ============================================================
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: ریاضی عمومی ۲
# ✅ Found English title: Calculus II
# 📝 Course type: پایه
# 📝 Unit type: نظری
# ✅ Extracted data: ریاضی عمومی ۲
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: مبانی کامپیوتر و برنامه‌سازی
# ✅ Found English title: Computer Fundamentals and Programming
# 📝 Course type: پایه
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: مبانی علوم ریاضی
# ✅ Found English title: Foundations of Mathematics
# 📝 Course type: پایه
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: احتمال مقدماتی
# ✅ Found English title: Elementary Probability
# 📝 Course type: پایه
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: تحلیل و مصورسازی داده‌ها
# ✅ Found English title: Data Analysis & Visualization
# 📝 Course type: پایه
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: مبانی علم داده‌ها
# ✅ Found English title: Foundation of Data Science
# 📝 Course type: پایه
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: کارگاه کامپیوتر ۱
# ✅ Found English title: Computer Workshop I
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: عملی
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: برنامه‌سازی پیشرفته
# ✅ Found English title: Advanced Programming
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: ساختمان داده‌ها
# ✅ Found English title: Data Structures
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: طراحی الگوریتم‌ها
# ✅ Found English title: Design of Algorithms
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: کارگاه کامپیوتر ۲
# ✅ Found English title: Computer Workshop II
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: عملی
#
# 📊 Parsing table with 7 lines
# ✅ Found Persian title: پایگاه داده‌ها
# ✅ Found English title: Databases
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 7 lines
# ✅ Found Persian title: مبانی ترکیبیات
# ✅ Found English title: Foundations of Combinatorics
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 7 lines
# ✅ Found Persian title: سری‌های زمانی کاربردی
# ✅ Found English title: Applied Time Series
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: یادگیری ماشینی
# ✅ Found English title: Machine Learning
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 7 lines
# ✅ Found Persian title: داده‌کاوی
# ✅ Found English title: Data Mining
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: روش‌های بهینه‌سازی برای علوم داده
# ✅ Found English title: Optimization Methods for Data Science
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: زبان تخصصی
# ✅ Found English title: English for Data Science
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: روش‌ شناسی آماری
# ✅ Found English title: Statistical Methodology
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 7 lines
# ✅ Found Persian title: رگرسیون ۱
# ✅ Found English title: Regression I
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 7 lines
# ✅ Found Persian title: شبیه‌سازی و مدل‌سازی
# ✅ Found English title: Computerized Simulation
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: مقدمه ای بر کلان داده ها
# ✅ Found English title: Introduction to Big Data
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: مقدمه ای بر فرآیندهای تصادفی
# ✅ Found English title: An Introduction to Stochastic Processes
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: آشنایی با پردازش زبان طبیعی
# ✅ Found English title: Introdution to Natural Language Processing
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: احتمال و کاربردها
# ✅ Found English title: Probability and Its Applications
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: روش‌های آماری چندمتغیره
# ✅ Found English title: Multivariate Statistical Methods
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: تجزیه و تحلیل داده‌های بیزی
# ✅ Found English title: Bayesian Data Analysis
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: تکنیک‌های نمونه گیری
# ✅ Found English title: Sampling Techniques
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: طرح و تحلیل آزمایش‌ها
# ✅ Found English title: Design and Analysis of Experiments
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: ناپارامتری و بازنمونه‌گیری
# ✅ Found English title: Nonparametric and Resampling Methods
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: ریاضیات پیشرفته برای علم داده‌ها
# ✅ Found English title: Advanced Mathematics for Data Science
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 6 lines
# ✅ Found Persian title: جبر خطی و نظریه ماتریس‌ها
# ✅ Found English title: Linear Algebra and Matrix Theory
# 📝 Course type: تخصصی الزامی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 7 lines
# ✅ Found Persian title: کارآموزی
# ✅ Found English title: Apprenticeship
# 📝 Course type: مهارتی
# 📝 Unit type: عملی
#
# 📊 Parsing table with 7 lines
# ✅ Found Persian title: کاربینی
# ✅ Found English title: Internship
# 📝 Course type: مهارتی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 7 lines
# ✅ Found Persian title: کارآفرینی
# ✅ Found English title: Entrepreneurship
# 📝 Course type: مهارتی
# 📝 Unit type: نظری
#
# 📊 Parsing table with 7 lines
# ✅ Found Persian title: مهارت‌های نرم شغلی
# ✅ Found English title: Job Soft Skills
# 📝 Course type: مهارتی
# 📝 Unit type: نظری
#
# 📦 Total courses extracted: 37
#
# 📊 Creating DataFrame from 37 valid courses
#
# 📈 Extraction Statistics:
# Total valid courses: 37
#
# 📊 Course types distribution:
# course_type
# تخصصی الزامی    26
# پایه             7
# مهارتی           4
# Name: count, dtype: int64
#
# 📊 Has exercises distribution:
# has_exercises
# دارد     27
#           5
# ندارد     5
# Name: count, dtype: int64
#
# 📋 Sample data (first 5):
#                        fa_title                               en_title  \
# 0                 ریاضی عمومی ۱                             Calculus I
# 1                 ریاضی عمومی ۲                            Calculus II
# 2  مبانی کامپیوتر و برنامه‌سازی  Computer Fundamentals and Programming
# 3              مبانی علوم ریاضی             Foundations of Mathematics
# 4                احتمال مقدماتی                 Elementary Probability
#
#   course_type units has_exercises
# 0        پایه     4          دارد
# 1        پایه     4          دارد
# 2        پایه     3          دارد
# 3        پایه     3          دارد
# 4        پایه     3          دارد
#
# 🎯 Generating files for 37 courses...
# 📚 Created 37 course mappings
# ✓ Created: base/Calculus-I.md
# ✓ Created: base/Calculus-II.md
# ✓ Created: base/Computer-Fundamentals-and-Programming.md
# ✓ Created: base/Foundations-of-Mathematics.md
# ✓ Created: base/Elementary-Probability.md
# ✓ Created: base/Data-Analysis-and-Visualization.md
# ✓ Created: base/Foundation-of-Data-Science.md
# ✓ Created: mandatory/Computer-Workshop-I.md
# ✓ Created: mandatory/Advanced-Programming.md
# ✓ Created: mandatory/Data-Structures.md
# ✓ Created: mandatory/Design-of-Algorithms.md
# ✓ Created: mandatory/Computer-Workshop-II.md
# ✓ Created: mandatory/Databases.md
# ✓ Created: mandatory/Foundations-of-Combinatorics.md
# ✓ Created: mandatory/Applied-Time-Series.md
# ✓ Created: mandatory/Machine-Learning.md
# ✓ Created: mandatory/Data-Mining.md
# ✓ Created: mandatory/Optimization-Methods-for-Data-Science.md
# ✓ Created: mandatory/English-for-Data-Science.md
# ✓ Created: mandatory/Statistical-Methodology.md
# ✓ Created: mandatory/Regression-I.md
# ✓ Created: mandatory/Computerized-Simulation.md
# ✓ Created: mandatory/Introduction-to-Big-Data.md
# ✓ Created: mandatory/An-Introduction-to-Stochastic-Processes.md
# ✓ Created: mandatory/Introdution-to-Natural-Language-Processing.md
# ✓ Created: mandatory/Probability-and-Its-Applications.md
# ✓ Created: mandatory/Multivariate-Statistical-Methods.md
# ✓ Created: mandatory/Bayesian-Data-Analysis.md
# ✓ Created: mandatory/Sampling-Techniques.md
# ✓ Created: mandatory/Design-and-Analysis-of-Experiments.md
# ✓ Created: mandatory/Nonparametric-and-Resampling-Methods.md
# ✓ Created: mandatory/Advanced-Mathematics-for-Data-Science.md
# ✓ Created: mandatory/Linear-Algebra-and-Matrix-Theory.md
# ✓ Created: skill/Apprenticeship.md
# ✓ Created: skill/Internship.md
# ✓ Created: skill/Entrepreneurship.md
# ✓ Created: skill/Job-Soft-Skills.md
#
# ✅ Successfully generated 37 files
#
# 📁 Files generated in folders:
#   📂 base/: 7 files
#   📂 mandatory/: 26 files
#   📂 skill/: 4 files
#
# ✅ Process completed successfully!
#
# 📋 Sample of extracted data (first 10):
#                        fa_title                               en_title   course_type units has_exercises
# 0                 ریاضی عمومی ۱                             Calculus I          پایه     4          دارد
# 1                 ریاضی عمومی ۲                            Calculus II          پایه     4          دارد
# 2  مبانی کامپیوتر و برنامه‌سازی  Computer Fundamentals and Programming          پایه     3          دارد
# 3              مبانی علوم ریاضی             Foundations of Mathematics          پایه     3          دارد
# 4                احتمال مقدماتی                 Elementary Probability          پایه     3          دارد
# 5      تحلیل و مصورسازی داده‌ها          Data Analysis & Visualization          پایه     3
# 6             مبانی علم داده‌ها             Foundation of Data Science          پایه     3          دارد
# 7             کارگاه کامپیوتر ۱                    Computer Workshop I  تخصصی الزامی     1         ندارد
# 8           برنامه‌سازی پیشرفته                   Advanced Programming  تخصصی الزامی     3          دارد
# 9               ساختمان داده‌ها                        Data Structures  تخصصی الزامی     3          دارد

# %%
# %run test_parser.py
